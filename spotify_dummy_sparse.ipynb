# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

df = pd.read_csv(r'F:\AppliedDataScience\data\ratingdf_likescore.csv')
print(len(df))

df2 = df[['session_id','track_id','rating']]

display(df2.shape)
# Out:
# 10000
# (10000, 3)

# %%
df2.head()
# Out:
#                                session_id  \
# 0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1  0_00079a23-1600-486a-91bd-5208be0c745a
# 2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb
# 3  0_013cc010-c476-4ad2-8972-73449e0b2ef4
# 4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290
#
#                                  track_id  rating
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     4.0
# 1  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.9
# 2  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     3.0
# 3  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     2.3
# 4  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     2.5

# %%
BYTES_TO_MB_DIV = 0.000001
def print_memory_usage_of_data_frame(df2):
    mem = round(df.memory_usage().sum() * BYTES_TO_MB_DIV, 3) 
    print("Memory usage is " + str(mem) + " MB")
    
print_memory_usage_of_data_frame(df2)
# Out:
# Memory usage is 1.12 MB

# %%
data_one_hot = pd.get_dummies(df2, columns=['session_id', 'track_id'])
display(data_one_hot.head())
display(data_one_hot.shape)
print_memory_usage_of_data_frame(data_one_hot)
# Out:
#    rating  session_id_0_00006f66-33e5-4de7-a324-2d18e439fc1e  \
# 0     4.0                                                  1
# 1     0.9                                                  0
# 2     3.0                                                  0
# 3     2.3                                                  0
# 4     2.5                                                  0
#
#    session_id_0_0000a72b-09ac-412f-b452-9b9e79bded8f  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    session_id_0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data_one_hot.shape
# Out:
# (10000, 13226)

# %%
data_one_hot2 = data_one_hot.drop('rating',axis = 1)

# %%
data_one_hot2.head()
# Out:
#    session_id_0_00006f66-33e5-4de7-a324-2d18e439fc1e  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    session_id_0_0000a72b-09ac-412f-b452-9b9e79bded8f  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    session_id_0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data_one_hot2.shape
# Out:
# (10000, 13225)

# %%
data_one_hot2_arr = data_one_hot2.values

# %%
data_one_hot2_new = data_one_hot2_arr.reshape(4,3306250)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a4c59b7f2cea> in <module>()
# ----> 1 data_one_hot2_new = data_one_hot2_arr.reshape(4,3306250)
#
# ValueError: cannot reshape array of size 132250000 into shape (4,3306250)

# %%
data_one_hot_sparse = data_one_hot2.to_sparse()
#display(data_one_hot_sparse.dtypes)
#print_memory_usage_of_sparse_data_frame(data_one_hot_sparse)

# %%
data_one_hot_sparse.head()
# Out:
#    session_id_0_00006f66-33e5-4de7-a324-2d18e439fc1e  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    session_id_0_0000a72b-09ac-412f-b452-9b9e79bded8f  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    session_id_0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
display(data_one_hot_sparse.dtypes)
# Out:
# session_id_0_00006f66-33e5-4de7-a324-2d18e439fc1e    uint8
# session_id_0_0000a72b-09ac-412f-b452-9b9e79bded8f    uint8
# session_id_0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a    uint8
# session_id_0_00016a3d-9076-4f67-918f-f29e3ce160dc    uint8
# session_id_0_00018b58-deb8-4f98-ac5e-d7e01b346130    uint8
# session_id_0_00027db1-ffe5-4b00-8eeb-8d8188451298    uint8
# session_id_0_00029482-6542-4d3e-bb9e-ffc988f58bd6    uint8
# session_id_0_0002fbb5-29c2-4d54-9636-e6d15e77b58c    uint8
# session_id_0_00030fe3-298d-4930-8534-fc5a9b82971b    uint8
# session_id_0_0003ac37-c70a-47a6-b9dc-b8b163826082    uint8
# session_id_0_0003e8a0-ea43-47fe-ac5a-8b502f4d38ef    uint8
# session_id_0_00041f88-6d8a-49ca-9a03-d0cfdbbafe5e    uint8
# session_id_0_00052b3c-a5f9-4b04-90ef-6378777d89d8    uint8
# session_id_0_00054512-7872-45c0-aaec-7b790f698a4f    uint8
# session_id_0_0005a7a1-196e-4e08-8928-39b9a3ca2e1a    uint8
# session_id_0_0006380b-324b-45db-a597-ac209b1375b2    uint8
# ...

# %%
print_memory_usage_of_data_frame(data_one_hot_sparse)
# Out:
# Memory usage is 1.12 MB

# %%
rating_df = data_one_hot[['rating']]

# %%
y = data_one_hot['rating']
X = data_one_hot[data_one_hot.columns.difference(['rating'])]
y_sparse = data_one_hot['rating']
X_sparse = data_one_hot[data_one_hot.columns.difference(['rating'])]
print_memory_usage_of_data_frame(X)
print_memory_usage_of_data_frame(X_sparse)
# Out:
# Memory usage is 1.12 MB
# Memory usage is 1.12 MB

# %%
vector_dict_df = pd.DataFrame(vector_dict)

# %%
vector_dict_df
# Out:
#                                     Pandas dataframe  \
# 0        session_id_0_00006f66-33e5-4de7-a324-2d1...
# 1  0       4.0
# 1       0.9
# 2       3.0
# 3       2....
#
#                              Sparse pandas dataframe
# 0        session_id_0_00006f66-33e5-4de7-a324-2d1...
# 1  0       4.0
# 1       0.9
# 2       3.0
# 3       2....

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
for key, item in vector_dict.items():
    
    #print(key)
    
    start = time.time()
    X_train, X_test, y_train, y_test = train_test_split(item[0], item[1], test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       session_id_0_00006f66-33e5-4de7-a324-2d18e439fc1e  \
# 9069                                                  0
# 2603                                                  0
# 7738                                                  0
# 1579                                                  0
# 5058                                                  0
#
#       session_id_0_0000a72b-09ac-412f-b452-9b9e79bded8f  \
# 9069                                                  0
# 2603                                                  0
# 7738                                                  0
# 1579                                                  0
# 5058                                                  0
#
#       session_id_0_00010fc5-b79e-4cdf-bc4c-f140d0f99a3a  \
# 9069                                                  0
# 2603                                                  0
# 7738                                                  0
# 1579                                                  0
# ...

# %%
y_train.head()
# Out:
# 9069    0.3
# 2603    0.5
# 7738    0.8
# 1579   -0.7
# 5058    2.8
# Name: rating, dtype: float64

# %%
clf = DecisionTreeClassifier(max_depth=None, max_leaf_nodes=20)

from sklearn import tree
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=20,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-48a2aac41443> in <module>()
# ----> 1 clf.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     138
#     139         if is_classification:
# --> 140             check_classification_targets(y)
#     141             y = np.copy(y)
#     142
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
# ...
