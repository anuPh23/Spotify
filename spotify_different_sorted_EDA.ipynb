# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
result_tf = pd.read_csv(r'F:\AppliedDataScience\data\multivariate_result_total.csv')

# %%
result_tf.head()
# Out:
#    Unnamed: 0                              session_id  \
# 0           0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1           1  0_00079a23-1600-486a-91bd-5208be0c745a
# 2           2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb
# 3           3  0_013cc010-c476-4ad2-8972-73449e0b2ef4
# 4           4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290
#
#                                  track_id  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 1  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
# 2  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 3  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 4  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
#
#    not_skipped  context_switch  hist_user_behavior_reason_start  \
# 0            1               0                              1.0
# 1            0               0                              0.3
# ...

# %%
main_score = result_tf['skip_score'] + result_tf['liking']
main_score = pd.DataFrame(main_score)
predicted_score = result_tf['p_skip_tf'] + result_tf['p_like_tf']
predicted_score = pd.DataFrame(predicted_score)
result_tf['main_score_tf'] = main_score
result_tf['predicted_score_tf'] = predicted_score

# %%
result_tf.head()
# Out:
#    Unnamed: 0                              session_id  \
# 0           0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1           1  0_00079a23-1600-486a-91bd-5208be0c745a
# 2           2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb
# 3           3  0_013cc010-c476-4ad2-8972-73449e0b2ef4
# 4           4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290
#
#                                  track_id  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 1  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
# 2  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 3  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 4  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
#
#    not_skipped  context_switch  hist_user_behavior_reason_start  \
# 0            1               0                              1.0
# 1            0               0                              0.3
# ...

# %%
diff = result_tf['main_score_tf'] - result_tf['predicted_score_tf']

# %%
sample = result_tf.head(20)

# %%
sample.head()
# Out:
#    Unnamed: 0                              session_id  \
# 0           0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1           1  0_00079a23-1600-486a-91bd-5208be0c745a
# 2           2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb
# 3           3  0_013cc010-c476-4ad2-8972-73449e0b2ef4
# 4           4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290
#
#                                  track_id  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 1  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
# 2  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 3  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 4  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
#
#    not_skipped  context_switch  hist_user_behavior_reason_start  \
# 0            1               0                              1.0
# 1            0               0                              0.3
# ...

# %%
diff_sample = sample['main_score_tf'] - sample['predicted_score_tf']

# %%
sample['diff_sample'] = diff_sample
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sample.head()
# Out:
#    Unnamed: 0                              session_id  \
# 0           0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1           1  0_00079a23-1600-486a-91bd-5208be0c745a
# 2           2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb
# 3           3  0_013cc010-c476-4ad2-8972-73449e0b2ef4
# 4           4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290
#
#                                  track_id  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 1  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
# 2  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 3  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 4  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
#
#    not_skipped  context_switch  hist_user_behavior_reason_start  \
# 0            1               0                              1.0
# 1            0               0                              0.3
# ...

# %%
th = sample.sort_values(by = 'diff_sample', axis=0, ascending=True, inplace=False)

# %%
th.head()
# Out:
#     Unnamed: 0                              session_id  \
# 5            5  0_01f86af2-cf48-42a6-9bf8-adb91f072909
# 6            6  0_02340c3b-c370-4c98-b759-87be85e11aa3
# 8            8  0_032c39c8-3a11-4f90-a3c5-38461b4d365d
# 10          10  0_04452794-0084-4712-9808-1845d338c8b9
# 18          18  0_0792cde4-90a0-45e9-bf9e-b4f78114f1bf
#
#                                   track_id  skip_1  skip_2  skip_3  \
# 5   t_0479f24c-27d2-46d6-a00c-7ec928f2b539      -1    -0.5     0.2
# 6   t_0479f24c-27d2-46d6-a00c-7ec928f2b539      -1    -0.5     0.2
# 8   t_0479f24c-27d2-46d6-a00c-7ec928f2b539      -1    -0.5     0.2
# 10  t_0479f24c-27d2-46d6-a00c-7ec928f2b539      -1    -0.5     0.2
# 18  t_0479f24c-27d2-46d6-a00c-7ec928f2b539      -1    -0.5     0.2
#
#     not_skipped  context_switch  hist_user_behavior_reason_start  \
# 5             0               0                              0.3
# 6             0               0                              0.3
# ...

# %%
th2 = th['track_id','diff_sample']]

# %%
th2
# Out:
#                                   track_id  diff_sample
# 5   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 6   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 8   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 10  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 18  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.328281
# 16  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.528281
# 1   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.328281
# 11  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.228281
# 15  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.228281
# 7   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.071719
# 9   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.271719
# 14  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.271719
# 17  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.371719
# 13  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.371719
# 3   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     1.071719
# 4   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     1.271719
# ...

# %%
th2.rename(columns = {'track_id':'track_id_recommended'}, inplace = True)
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\pandas\core\frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
th2.rename(columns = {'diff_sample':'diff_sorted'},inplace = True)
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\pandas\core\frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
th2.head()
# Out:
#                       track_id_recommended  diff_sorted
# 5   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 6   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 8   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 10  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 18  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.328281

# %%
sample.head()
# Out:
#    Unnamed: 0                              session_id  \
# 0           0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1           1  0_00079a23-1600-486a-91bd-5208be0c745a
# 2           2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb
# 3           3  0_013cc010-c476-4ad2-8972-73449e0b2ef4
# 4           4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290
#
#                                  track_id  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 1  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
# 2  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 3  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.0
# 4  t_0479f24c-27d2-46d6-a00c-7ec928f2b539       0     0.0     0.2
#
#    not_skipped  context_switch  hist_user_behavior_reason_start  \
# 0            1               0                              1.0
# 1            0               0                              0.3
# ...

# %%
sample2 = sample

# %%
session_id_new = th2['session_id_new']
track_id_recommended = th2['track_id_new']
diff_sorted = th2['diff_sorted']

# %%
session_id_new = pd.DataFrame(session_id_new)
track_id_new = pd.DataFrame(track_id_recommended)

# %%
index_value2 = pd.DataFrame(session_id_new.index)

# %%
index_value2.head()
# Out:
#     0
# 0   5
# 1   6
# 2   8
# 3  10
# 4  18

# %%
th2 = pd.DataFrame(th2)

# %%
th2
# Out:
#                       track_id_recommended  diff_sorted
# 5   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 6   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 8   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 10  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.928281
# 18  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -1.328281
# 16  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.528281
# 1   t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.328281
# 11  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.228281
# 15  t_0479f24c-27d2-46d6-a00c-7ec928f2b539    -0.228281
# 7   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.071719
# 9   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.271719
# 14  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.271719
# 17  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.371719
# 13  t_0479f24c-27d2-46d6-a00c-7ec928f2b539     0.371719
# 3   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     1.071719
# 4   t_0479f24c-27d2-46d6-a00c-7ec928f2b539     1.271719
# ...

# %%
result_tf_final = result_tf

# %%
result_tf_final
# Out:
#         Unnamed: 0                              session_id  \
# 0                0  0_00006f66-33e5-4de7-a324-2d18e439fc1e
# 1                1  0_00079a23-1600-486a-91bd-5208be0c745a
# 2                2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb
# 3                3  0_013cc010-c476-4ad2-8972-73449e0b2ef4
# 4                4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290
# 5                5  0_01f86af2-cf48-42a6-9bf8-adb91f072909
# 6                6  0_02340c3b-c370-4c98-b759-87be85e11aa3
# 7                7  0_02a8ebbd-5a12-4343-a7da-2ea912102f90
# 8                8  0_032c39c8-3a11-4f90-a3c5-38461b4d365d
# 9                9  0_03373b7c-3c30-4bac-a909-1a4ecc310797
# 10              10  0_04452794-0084-4712-9808-1845d338c8b9
# 11              11  0_04ab5699-1f6a-40ef-b8a6-9ebad09e85f6
# 12              12  0_05219b57-68f2-4eac-a139-85cef6f3809b
# 13              13  0_05b0cc6b-6615-44bd-ba6d-d6737cd5324a
# 14              14  0_05de15dc-d2a9-43aa-b00e-e7298df02293
# ...

# %%
diff_sample_final = result_tf_final['main_score_tf'] - result_tf_final['predicted_score_tf']

# %%
result_tf_final['diff'] = diff_sample_final

# %%
result_tf_final = result_tf_final.sort_values(by = 'diff', axis=0, ascending=True, inplace=False)

# %%
result_tf_final.head(15)
# Out:
#         Unnamed: 0                              session_id  \
# 56654        56654  0_0e503996-ba9a-4b11-bf9a-0daba0489096
# 67968        67968  0_0c78ca8f-f70c-4081-b592-29de00736370
# 10756        10756  0_0da624e8-56f9-4627-bf09-eee17df20658
# 142214      142214  0_07699120-a5f7-4f6e-bdb2-3e585abe25fe
# 51172        51172  0_0c14d2ce-da44-419a-be19-6d3cbe45efe6
# 139461      139461  0_06d7fd53-391b-4505-a357-7d6cd795e971
# 30642        30642  0_0781bb66-3654-4785-9df1-6b9326c4a608
# 89136        89136  0_040fbb69-135a-46c2-8942-fa3b76a28032
# 105455      105455  0_0a063bd5-76e4-4bb6-b93f-c0796d5bb666
# 69380        69380  0_01ed1812-18d8-4490-a0f2-3c526ed436e3
# 8207          8207  0_0a4a1e5b-09be-424a-b38d-d638c362ddeb
# 57277        57277  0_04e1f1eb-6b7c-4894-b863-6d8387f5ff5f
# 164595      164595  0_0d83feac-289e-4c88-ae1a-b04fb2e1f8d9
# 69475        69475  0_04f0172d-f65d-4ecc-8494-1952ad17bbfa
# 166168      166168  0_0e0fb0d2-584f-4969-acb7-cd63c5501d88
#
# ...
