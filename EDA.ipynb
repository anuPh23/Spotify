# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
bb = pd.read_csv(r'F:\AppliedDataScience\data\ubb_p1.csv')
nbb = pd.read_csv(r'F:\AppliedDataScience\data\unbb_p1.csv')

# %%
bb.head()
# Out:
#    Unnamed: 0                              track_id_x  \
# 0           0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 1           2  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 2           5  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 3           8  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 4           9  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
#
#                                session_id  session_position  session_length  \
# 0  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1              20
# 1  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb                 6              20
# 2  0_01f86af2-cf48-42a6-9bf8-adb91f072909                 7              20
# 3  0_032c39c8-3a11-4f90-a3c5-38461b4d365d                13              19
# 4  0_03373b7c-3c30-4bac-a909-1a4ecc310797                 5              19
#
#                                track_id_y  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False   False
# ...

# %%
nbb.head()
# Out:
#    Unnamed: 0                              track_id_x  \
# 0           1  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 1           3  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 2           4  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 3           6  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
# 4           7  t_0479f24c-27d2-46d6-a00c-7ec928f2b539
#
#                                session_id  session_position  session_length  \
# 0  0_00079a23-1600-486a-91bd-5208be0c745a                 7              12
# 1  0_013cc010-c476-4ad2-8972-73449e0b2ef4                 9              13
# 2  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290                 7              12
# 3  0_02340c3b-c370-4c98-b759-87be85e11aa3                 8              20
# 4  0_02a8ebbd-5a12-4343-a7da-2ea912102f90                 2              20
#
#                                track_id_y  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False    True
# ...

# %%
bb.columns
# Out:
# Index(['Unnamed: 0', 'track_id_x', 'session_id', 'session_position',
#        'session_length', 'track_id_y', 'skip_1', 'skip_2', 'skip_3',
#        'not_skipped', 'context_switch', 'no_pause_before_play',
#        'short_pause_before_play', 'long_pause_before_play',
#        'hist_user_behavior_n_seekfwd', 'hist_user_behavior_n_seekback',
#        'hist_user_behavior_is_shuffle', 'hour_of_day', 'date', 'premium',
#        'context_type', 'hist_user_behavior_reason_start',
#        'hist_user_behavior_reason_end', 'label', 'duration', 'release_year',
#        'us_popularity_estimate', 'acousticness', 'beat_strength', 'bounciness',
#        'danceability', 'dyn_range_mean', 'energy', 'flatness',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mechanism', 'mode',
#        'organism', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2',
# ...

# %%
dat = pd.read_csv(r'F:\AppliedDataScience\data\dat.csv')

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['danceability'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

sns.distplot(dat['danceability'])
sns.distplot(dat['bounciness'])
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['dyn_range_mean'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

sns.distplot(dat['dyn_range_mean'])
sns.distplot(dat['bounciness'])
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['energy'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

sns.distplot(dat['energy'])
sns.distplot(dat['bounciness'])
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['flatness'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

sns.distplot(dat['flatness'])
sns.distplot(dat['bounciness'])
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['key'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['loudness'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['mechanism'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['organism'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['speechiness'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['tempo'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['time_signature'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['valence'],dat['bounciness'],s = dat['liveness'] * 70.5,c = dat['predicted_output'], alpha=1.0)

plt.show()

# %%
len(bb)

# %%
len(nbb)

# %%
#!pip3 install -U seaborn
