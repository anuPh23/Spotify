# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dat = pd.read_csv(r'F:\AppliedDataScience\data\dat.csv')

# %%
dat.head()
# Out:
#    Unnamed: 0                              session_id  session_position  \
# 0           0  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 1           1  0_00079a23-1600-486a-91bd-5208be0c745a                 7
# 2           2  0_012b0fb4-0cc3-429f-9a78-cc6e622153fb                 6
# 3           3  0_013cc010-c476-4ad2-8972-73449e0b2ef4                 9
# 4           4  0_01a5f0dc-9938-48c9-92f1-c7e51f34d290                 7
#
#    session_length                                track_id  skip_1  skip_2  \
# 0              20  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False
# 1              12  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False
# 2              20  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False
# 3              13  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False
# 4              12  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False
#
#    skip_3  not_skipped  context_switch       ...          valence  \
# ...

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['liveness'],c = dat['predicted_output'], alpha=1.2)
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['danceability'],dat['bounciness'],s = dat['liveness'],c = dat['predicted_output'], alpha=1.2)
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['energy'],dat['bounciness'],s = dat['liveness']/0.235,c = dat['predicted_output'], alpha=1.2)
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_0'],c = dat['predicted_output'], alpha=1.2)
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_1'],c = dat['predicted_output'], alpha=1.2)
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_2'],c = dat['predicted_output'], alpha=1.2)
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_3'],c = dat['predicted_output'], alpha=1.2)
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.figure(figsize=(10, 8))
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_4'],c = dat['predicted_output'], alpha=1.2)
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_0'],c = dat['predicted_output'], alpha=1.2)
plt.show()
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_1'],c = dat['predicted_output'], alpha=1.2)
plt.show()
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_2'],c = dat['predicted_output'], alpha=1.2)
plt.show()
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_3'],c = dat['predicted_output'], alpha=1.2)
plt.show()
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_4'],c = dat['predicted_output'], alpha=1.2)
plt.show()
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['acoustic_vector_5'],c = dat['predicted_output'], alpha=1.2)
plt.show()
# Out:
# C:\Users\Ted\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
len(dat.session_position.unique())
# Out:
# 20

# %%
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['liveness'],c = dat['session_position'], alpha=1.2)
plt.show()
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['liveness'],c = dat['session_length'], alpha=1.2)
plt.show()
plt.scatter(dat['beat_strength'],dat['bounciness'] ,s = dat['liveness'],c = dat['predicted_output'], alpha=1.2)
plt.show()

# %%
av = dat[['acoustic_vector_0','acoustic_vector_1','acoustic_vector_2','acoustic_vector_3','acoustic_vector_4','acoustic_vector_5']]

# %%
av.describe()
% matplotlib inline

# %%
sns.heatmap(av)
